# %% [markdown]
# <a href="https://colab.research.google.com/github/newmantic/DQN/blob/main/DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# %%
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=64):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %%
class DQNAgent:
    def __init__(self, state_size, action_size, hidden_size=64, gamma=0.99, learning_rate=0.001, batch_size=64, memory_size=10000, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995):
        self.state_size = state_size
        self.action_size = action_size
        self.hidden_size = hidden_size
        self.gamma = gamma
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.memory = deque(maxlen=memory_size)
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_end
        self.epsilon_decay = epsilon_decay

        # Q-Network
        self.q_network = QNetwork(state_size, action_size, hidden_size)
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=learning_rate)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def choose_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.choice(range(self.action_size))  # Explore
        else:
            state = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                q_values = self.q_network(state)
            return np.argmax(q_values.cpu().numpy())  # Exploit

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        minibatch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = torch.FloatTensor(states)
        actions = torch.LongTensor(actions).unsqueeze(1)
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        next_states = torch.FloatTensor(next_states)
        dones = torch.FloatTensor(dones).unsqueeze(1)

        current_q_values = self.q_network(states).gather(1, actions)
        next_q_values = self.q_network(next_states).max(1)[0].unsqueeze(1)
        target_q_values = rewards + self.gamma * next_q_values * (1 - dones)

        loss = nn.MSELoss()(current_q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, path):
        self.q_network.load_state_dict(torch.load(path))

    def save(self, path):
        torch.save(self.q_network.state_dict(), path)

# %%
class Simple1DEnv:
    def __init__(self, length=10, start=0, goal=9):
        self.length = length
        self.start = start
        self.goal = goal
        self.state = start

    def reset(self):
        self.state = self.start
        return self.state

    def step(self, action):
        if action == 0:  # move left
            self.state = max(0, self.state - 1)
        elif action == 1:  # move right
            self.state = min(self.length - 1, self.state + 1)

        if self.state == self.goal:
            return self.state, 1, True  # reached goal, reward 1
        else:
            return self.state, -1, False  # not at goal, penalty -1

# %%
def train_dqn():
    env = Simple1DEnv()
    state_size = 1  # since the state is just the position in the 1D space
    action_size = 2  # two possible actions: move left or right

    agent = DQNAgent(state_size, action_size, hidden_size=24, gamma=0.99, learning_rate=0.001, batch_size=32, memory_size=2000, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995)

    n_episodes = 500
    max_steps = 100

    for e in range(n_episodes):
        state = env.reset()
        state = np.reshape(state, [1])
        for time in range(max_steps):
            action = agent.choose_action(state)
            next_state, reward, done = env.step(action)
            next_state = np.reshape(next_state, [1])
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            if done:
                print(f"Episode: {e+1}/{n_episodes}, score: {time+1}, epsilon: {agent.epsilon:.2}")
                break
            agent.replay()

    return agent

# Train the DQN agent
dqn_agent = train_dqn()

# Save the trained model
dqn_agent.save("dqn_model.pth")
# Out:
# Episode: 1/500, score: 29, epsilon: 1.0
# <ipython-input-3-99dd93da2bc5>:37: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   states = torch.FloatTensor(states)
# Episode: 26/500, score: 80, epsilon: 0.01
# Episode: 27/500, score: 9, epsilon: 0.01
# Episode: 28/500, score: 9, epsilon: 0.01
# Episode: 29/500, score: 9, epsilon: 0.01
# Episode: 30/500, score: 9, epsilon: 0.01
# Episode: 31/500, score: 9, epsilon: 0.01
# Episode: 32/500, score: 9, epsilon: 0.01
# Episode: 33/500, score: 9, epsilon: 0.01
# Episode: 34/500, score: 9, epsilon: 0.01
# Episode: 35/500, score: 9, epsilon: 0.01
# Episode: 36/500, score: 9, epsilon: 0.01
# Episode: 37/500, score: 9, epsilon: 0.01
# Episode: 38/500, score: 9, epsilon: 0.01
# Episode: 39/500, score: 9, epsilon: 0.01
# Episode: 40/500, score: 9, epsilon: 0.01
# Episode: 41/500, score: 9, epsilon: 0.01
# Episode: 42/500, score: 9, epsilon: 0.01
# Episode: 43/500, score: 9, epsilon: 0.01
# Episode: 44/500, score: 9, epsilon: 0.01
# Episode: 45/500, score: 9, epsilon: 0.01
# Episode: 46/500, score: 9, epsilon: 0.01
# Episode: 47/500, score: 9, epsilon: 0.01
# Episode: 48/500, score: 9, epsilon: 0.01
# Episode: 49/500, score: 9, epsilon: 0.01
# Episode: 50/500, score: 9, epsilon: 0.01
# Episode: 51/500, score: 9, epsilon: 0.01
# Episode: 52/500, score: 9, epsilon: 0.01
# Episode: 53/500, score: 9, epsilon: 0.01
# Episode: 54/500, score: 9, epsilon: 0.01
# Episode: 55/500, score: 9, epsilon: 0.01
# Episode: 56/500, score: 9, epsilon: 0.01
# Episode: 57/500, score: 9, epsilon: 0.01
# Episode: 58/500, score: 9, epsilon: 0.01
# Episode: 59/500, score: 9, epsilon: 0.01
# Episode: 60/500, score: 9, epsilon: 0.01
# Episode: 61/500, score: 9, epsilon: 0.01
# Episode: 62/500, score: 9, epsilon: 0.01
# Episode: 63/500, score: 9, epsilon: 0.01
# Episode: 64/500, score: 11, epsilon: 0.01
# Episode: 65/500, score: 9, epsilon: 0.01
# Episode: 66/500, score: 9, epsilon: 0.01
# Episode: 67/500, score: 9, epsilon: 0.01
# Episode: 68/500, score: 11, epsilon: 0.01
# Episode: 69/500, score: 9, epsilon: 0.01
# Episode: 70/500, score: 9, epsilon: 0.01
# Episode: 71/500, score: 9, epsilon: 0.01
# Episode: 72/500, score: 9, epsilon: 0.01
# Episode: 73/500, score: 9, epsilon: 0.01
# Episode: 74/500, score: 9, epsilon: 0.01
# Episode: 75/500, score: 9, epsilon: 0.01
# Episode: 76/500, score: 9, epsilon: 0.01
# Episode: 77/500, score: 9, epsilon: 0.01
# Episode: 78/500, score: 9, epsilon: 0.01
# Episode: 79/500, score: 9, epsilon: 0.01
# Episode: 80/500, score: 11, epsilon: 0.01
# Episode: 81/500, score: 9, epsilon: 0.01
# Episode: 82/500, score: 9, epsilon: 0.01
# Episode: 83/500, score: 9, epsilon: 0.01
# Episode: 84/500, score: 9, epsilon: 0.01
# Episode: 85/500, score: 9, epsilon: 0.01
# Episode: 86/500, score: 9, epsilon: 0.01
# Episode: 87/500, score: 9, epsilon: 0.01
# Episode: 88/500, score: 9, epsilon: 0.01
# Episode: 89/500, score: 9, epsilon: 0.01
# Episode: 90/500, score: 9, epsilon: 0.01
# Episode: 91/500, score: 9, epsilon: 0.01
# Episode: 92/500, score: 11, epsilon: 0.01
# Episode: 93/500, score: 9, epsilon: 0.01
# Episode: 94/500, score: 9, epsilon: 0.01
# Episode: 95/500, score: 9, epsilon: 0.01
# Episode: 96/500, score: 9, epsilon: 0.01
# Episode: 97/500, score: 9, epsilon: 0.01
# Episode: 98/500, score: 9, epsilon: 0.01
# Episode: 99/500, score: 9, epsilon: 0.01
# Episode: 100/500, score: 9, epsilon: 0.01
# Episode: 101/500, score: 9, epsilon: 0.01
# Episode: 102/500, score: 9, epsilon: 0.01
# Episode: 103/500, score: 9, epsilon: 0.01
# Episode: 104/500, score: 9, epsilon: 0.01
# Episode: 105/500, score: 9, epsilon: 0.01
# Episode: 106/500, score: 9, epsilon: 0.01
# Episode: 107/500, score: 9, epsilon: 0.01
# Episode: 108/500, score: 9, epsilon: 0.01
# Episode: 109/500, score: 9, epsilon: 0.01
# Episode: 110/500, score: 9, epsilon: 0.01
# Episode: 111/500, score: 9, epsilon: 0.01
# Episode: 112/500, score: 9, epsilon: 0.01
# Episode: 113/500, score: 11, epsilon: 0.01
# Episode: 114/500, score: 9, epsilon: 0.01
# Episode: 115/500, score: 9, epsilon: 0.01
# Episode: 116/500, score: 9, epsilon: 0.01
# Episode: 117/500, score: 9, epsilon: 0.01
# Episode: 118/500, score: 9, epsilon: 0.01
# Episode: 119/500, score: 9, epsilon: 0.01
# Episode: 120/500, score: 9, epsilon: 0.01
# Episode: 121/500, score: 9, epsilon: 0.01
# Episode: 122/500, score: 9, epsilon: 0.01
# Episode: 123/500, score: 9, epsilon: 0.01
# Episode: 124/500, score: 11, epsilon: 0.01
# Episode: 125/500, score: 9, epsilon: 0.01
# Episode: 126/500, score: 9, epsilon: 0.01
# Episode: 127/500, score: 9, epsilon: 0.01
# Episode: 128/500, score: 9, epsilon: 0.01
# Episode: 129/500, score: 9, epsilon: 0.01
# Episode: 130/500, score: 9, epsilon: 0.01
# Episode: 131/500, score: 9, epsilon: 0.01
# Episode: 132/500, score: 9, epsilon: 0.01
# Episode: 133/500, score: 9, epsilon: 0.01
# Episode: 134/500, score: 9, epsilon: 0.01
# Episode: 135/500, score: 9, epsilon: 0.01
# Episode: 136/500, score: 9, epsilon: 0.01
# Episode: 137/500, score: 9, epsilon: 0.01
# Episode: 138/500, score: 13, epsilon: 0.01
# Episode: 139/500, score: 9, epsilon: 0.01
# Episode: 140/500, score: 9, epsilon: 0.01
# Episode: 141/500, score: 9, epsilon: 0.01
# Episode: 142/500, score: 9, epsilon: 0.01
# Episode: 143/500, score: 9, epsilon: 0.01
# Episode: 144/500, score: 9, epsilon: 0.01
# Episode: 145/500, score: 9, epsilon: 0.01
# Episode: 146/500, score: 9, epsilon: 0.01
# Episode: 147/500, score: 9, epsilon: 0.01
# Episode: 148/500, score: 9, epsilon: 0.01
# Episode: 149/500, score: 9, epsilon: 0.01
# Episode: 150/500, score: 9, epsilon: 0.01
# Episode: 151/500, score: 9, epsilon: 0.01
# Episode: 152/500, score: 9, epsilon: 0.01
# Episode: 153/500, score: 9, epsilon: 0.01
# Episode: 154/500, score: 11, epsilon: 0.01
# Episode: 155/500, score: 9, epsilon: 0.01
# Episode: 156/500, score: 9, epsilon: 0.01
# Episode: 157/500, score: 9, epsilon: 0.01
# Episode: 158/500, score: 9, epsilon: 0.01
# Episode: 159/500, score: 9, epsilon: 0.01
# Episode: 160/500, score: 9, epsilon: 0.01
# Episode: 161/500, score: 9, epsilon: 0.01
# Episode: 162/500, score: 9, epsilon: 0.01
# Episode: 163/500, score: 9, epsilon: 0.01
# Episode: 164/500, score: 9, epsilon: 0.01
# Episode: 165/500, score: 11, epsilon: 0.01
# Episode: 166/500, score: 9, epsilon: 0.01
# Episode: 167/500, score: 9, epsilon: 0.01
# Episode: 168/500, score: 9, epsilon: 0.01
# Episode: 169/500, score: 9, epsilon: 0.01
# Episode: 170/500, score: 9, epsilon: 0.01
# Episode: 171/500, score: 9, epsilon: 0.01
# Episode: 172/500, score: 9, epsilon: 0.01
# Episode: 173/500, score: 9, epsilon: 0.01
# Episode: 174/500, score: 9, epsilon: 0.01
# Episode: 175/500, score: 9, epsilon: 0.01
# Episode: 176/500, score: 9, epsilon: 0.01
# Episode: 177/500, score: 9, epsilon: 0.01
# Episode: 178/500, score: 9, epsilon: 0.01
# Episode: 179/500, score: 9, epsilon: 0.01
# Episode: 180/500, score: 9, epsilon: 0.01
# Episode: 181/500, score: 9, epsilon: 0.01
# Episode: 182/500, score: 9, epsilon: 0.01
# Episode: 183/500, score: 9, epsilon: 0.01
# Episode: 184/500, score: 9, epsilon: 0.01
# Episode: 185/500, score: 9, epsilon: 0.01
# Episode: 186/500, score: 9, epsilon: 0.01
# Episode: 187/500, score: 9, epsilon: 0.01
# Episode: 188/500, score: 10, epsilon: 0.01
# Episode: 189/500, score: 9, epsilon: 0.01
# Episode: 190/500, score: 9, epsilon: 0.01
# Episode: 191/500, score: 9, epsilon: 0.01
# Episode: 192/500, score: 9, epsilon: 0.01
# Episode: 193/500, score: 11, epsilon: 0.01
# Episode: 194/500, score: 9, epsilon: 0.01
# Episode: 195/500, score: 11, epsilon: 0.01
# Episode: 196/500, score: 9, epsilon: 0.01
# Episode: 197/500, score: 9, epsilon: 0.01
# Episode: 198/500, score: 9, epsilon: 0.01
# Episode: 199/500, score: 9, epsilon: 0.01
# Episode: 200/500, score: 9, epsilon: 0.01
# Episode: 201/500, score: 9, epsilon: 0.01
# Episode: 202/500, score: 9, epsilon: 0.01
# Episode: 203/500, score: 9, epsilon: 0.01
# Episode: 204/500, score: 9, epsilon: 0.01
# Episode: 205/500, score: 9, epsilon: 0.01
# Episode: 206/500, score: 9, epsilon: 0.01
# Episode: 207/500, score: 9, epsilon: 0.01
# Episode: 208/500, score: 9, epsilon: 0.01
# Episode: 209/500, score: 9, epsilon: 0.01
# Episode: 210/500, score: 9, epsilon: 0.01
# Episode: 211/500, score: 9, epsilon: 0.01
# Episode: 212/500, score: 9, epsilon: 0.01
# Episode: 213/500, score: 9, epsilon: 0.01
# Episode: 214/500, score: 9, epsilon: 0.01
# Episode: 215/500, score: 9, epsilon: 0.01
# Episode: 216/500, score: 9, epsilon: 0.01
# Episode: 217/500, score: 9, epsilon: 0.01
# Episode: 218/500, score: 9, epsilon: 0.01
# Episode: 219/500, score: 9, epsilon: 0.01
# Episode: 220/500, score: 9, epsilon: 0.01
# Episode: 221/500, score: 9, epsilon: 0.01
# Episode: 222/500, score: 9, epsilon: 0.01
# Episode: 223/500, score: 9, epsilon: 0.01
# Episode: 224/500, score: 9, epsilon: 0.01
# Episode: 225/500, score: 9, epsilon: 0.01
# Episode: 226/500, score: 9, epsilon: 0.01
# Episode: 227/500, score: 9, epsilon: 0.01
# Episode: 228/500, score: 9, epsilon: 0.01
# Episode: 229/500, score: 9, epsilon: 0.01
# Episode: 230/500, score: 9, epsilon: 0.01
# Episode: 231/500, score: 9, epsilon: 0.01
# Episode: 232/500, score: 9, epsilon: 0.01
# Episode: 233/500, score: 9, epsilon: 0.01
# Episode: 234/500, score: 9, epsilon: 0.01
# Episode: 235/500, score: 9, epsilon: 0.01
# Episode: 236/500, score: 9, epsilon: 0.01
# Episode: 237/500, score: 9, epsilon: 0.01
# Episode: 238/500, score: 9, epsilon: 0.01
# Episode: 239/500, score: 9, epsilon: 0.01
# Episode: 240/500, score: 9, epsilon: 0.01
# Episode: 241/500, score: 9, epsilon: 0.01
# Episode: 242/500, score: 9, epsilon: 0.01
# Episode: 243/500, score: 9, epsilon: 0.01
# Episode: 244/500, score: 9, epsilon: 0.01
# Episode: 245/500, score: 9, epsilon: 0.01
# Episode: 246/500, score: 9, epsilon: 0.01
# Episode: 247/500, score: 9, epsilon: 0.01
# Episode: 248/500, score: 9, epsilon: 0.01
# Episode: 249/500, score: 9, epsilon: 0.01
# Episode: 250/500, score: 9, epsilon: 0.01
# Episode: 251/500, score: 9, epsilon: 0.01
# Episode: 252/500, score: 9, epsilon: 0.01
# Episode: 253/500, score: 9, epsilon: 0.01
# Episode: 254/500, score: 9, epsilon: 0.01
# Episode: 255/500, score: 9, epsilon: 0.01
# Episode: 256/500, score: 9, epsilon: 0.01
# Episode: 257/500, score: 9, epsilon: 0.01
# Episode: 258/500, score: 9, epsilon: 0.01
# Episode: 259/500, score: 9, epsilon: 0.01
# Episode: 260/500, score: 9, epsilon: 0.01
# Episode: 261/500, score: 9, epsilon: 0.01
# Episode: 262/500, score: 9, epsilon: 0.01
# Episode: 263/500, score: 9, epsilon: 0.01
# Episode: 264/500, score: 9, epsilon: 0.01
# Episode: 265/500, score: 9, epsilon: 0.01
# Episode: 266/500, score: 9, epsilon: 0.01
# Episode: 267/500, score: 9, epsilon: 0.01
# Episode: 268/500, score: 9, epsilon: 0.01
# Episode: 269/500, score: 9, epsilon: 0.01
# Episode: 270/500, score: 9, epsilon: 0.01
# Episode: 271/500, score: 9, epsilon: 0.01
# Episode: 272/500, score: 9, epsilon: 0.01
# Episode: 273/500, score: 9, epsilon: 0.01
# Episode: 274/500, score: 9, epsilon: 0.01
# Episode: 275/500, score: 9, epsilon: 0.01
# Episode: 276/500, score: 9, epsilon: 0.01
# Episode: 277/500, score: 9, epsilon: 0.01
# Episode: 278/500, score: 9, epsilon: 0.01
# Episode: 279/500, score: 9, epsilon: 0.01
# Episode: 280/500, score: 9, epsilon: 0.01
# Episode: 281/500, score: 9, epsilon: 0.01
# Episode: 282/500, score: 9, epsilon: 0.01
# Episode: 283/500, score: 9, epsilon: 0.01
# Episode: 284/500, score: 9, epsilon: 0.01
# Episode: 285/500, score: 9, epsilon: 0.01
# Episode: 286/500, score: 9, epsilon: 0.01
# Episode: 287/500, score: 9, epsilon: 0.01
# Episode: 288/500, score: 9, epsilon: 0.01
# Episode: 289/500, score: 9, epsilon: 0.01
# Episode: 290/500, score: 9, epsilon: 0.01
# Episode: 291/500, score: 9, epsilon: 0.01
# Episode: 292/500, score: 9, epsilon: 0.01
# Episode: 293/500, score: 9, epsilon: 0.01
# Episode: 294/500, score: 9, epsilon: 0.01
# Episode: 295/500, score: 9, epsilon: 0.01
# Episode: 296/500, score: 9, epsilon: 0.01
# Episode: 297/500, score: 9, epsilon: 0.01
# Episode: 298/500, score: 9, epsilon: 0.01
# Episode: 299/500, score: 9, epsilon: 0.01
# Episode: 300/500, score: 9, epsilon: 0.01
# Episode: 301/500, score: 9, epsilon: 0.01
# Episode: 302/500, score: 9, epsilon: 0.01
# Episode: 303/500, score: 9, epsilon: 0.01
# Episode: 304/500, score: 9, epsilon: 0.01
# Episode: 305/500, score: 9, epsilon: 0.01
# Episode: 306/500, score: 9, epsilon: 0.01
# Episode: 307/500, score: 9, epsilon: 0.01
# Episode: 308/500, score: 9, epsilon: 0.01
# Episode: 309/500, score: 9, epsilon: 0.01
# Episode: 310/500, score: 9, epsilon: 0.01
# Episode: 311/500, score: 9, epsilon: 0.01
# Episode: 312/500, score: 9, epsilon: 0.01
# Episode: 313/500, score: 9, epsilon: 0.01
# Episode: 314/500, score: 9, epsilon: 0.01
# Episode: 315/500, score: 9, epsilon: 0.01
# Episode: 316/500, score: 9, epsilon: 0.01
# Episode: 317/500, score: 9, epsilon: 0.01
# Episode: 318/500, score: 9, epsilon: 0.01
# Episode: 319/500, score: 9, epsilon: 0.01
# Episode: 320/500, score: 9, epsilon: 0.01
# Episode: 321/500, score: 9, epsilon: 0.01
# Episode: 322/500, score: 9, epsilon: 0.01
# Episode: 323/500, score: 9, epsilon: 0.01
# Episode: 324/500, score: 9, epsilon: 0.01
# Episode: 325/500, score: 9, epsilon: 0.01
# Episode: 326/500, score: 9, epsilon: 0.01
# Episode: 327/500, score: 10, epsilon: 0.01
# Episode: 328/500, score: 9, epsilon: 0.01
# Episode: 329/500, score: 9, epsilon: 0.01
# Episode: 330/500, score: 9, epsilon: 0.01
# Episode: 331/500, score: 9, epsilon: 0.01
# Episode: 332/500, score: 9, epsilon: 0.01
# Episode: 333/500, score: 9, epsilon: 0.01
# Episode: 334/500, score: 9, epsilon: 0.01
# Episode: 335/500, score: 11, epsilon: 0.01
# Episode: 336/500, score: 9, epsilon: 0.01
# Episode: 337/500, score: 9, epsilon: 0.01
# Episode: 338/500, score: 9, epsilon: 0.01
# Episode: 339/500, score: 9, epsilon: 0.01
# Episode: 340/500, score: 9, epsilon: 0.01
# Episode: 341/500, score: 9, epsilon: 0.01
# Episode: 342/500, score: 9, epsilon: 0.01
# Episode: 343/500, score: 9, epsilon: 0.01
# Episode: 344/500, score: 9, epsilon: 0.01
# Episode: 345/500, score: 9, epsilon: 0.01
# Episode: 346/500, score: 9, epsilon: 0.01
# Episode: 347/500, score: 9, epsilon: 0.01
# Episode: 348/500, score: 9, epsilon: 0.01
# Episode: 349/500, score: 9, epsilon: 0.01
# Episode: 350/500, score: 9, epsilon: 0.01
# Episode: 351/500, score: 9, epsilon: 0.01
# Episode: 352/500, score: 9, epsilon: 0.01
# Episode: 353/500, score: 9, epsilon: 0.01
# Episode: 354/500, score: 9, epsilon: 0.01
# Episode: 355/500, score: 9, epsilon: 0.01
# Episode: 356/500, score: 9, epsilon: 0.01
# Episode: 357/500, score: 9, epsilon: 0.01
# Episode: 358/500, score: 9, epsilon: 0.01
# Episode: 359/500, score: 9, epsilon: 0.01
# Episode: 360/500, score: 9, epsilon: 0.01
# Episode: 361/500, score: 9, epsilon: 0.01
# Episode: 362/500, score: 9, epsilon: 0.01
# Episode: 363/500, score: 9, epsilon: 0.01
# Episode: 364/500, score: 9, epsilon: 0.01
# Episode: 365/500, score: 9, epsilon: 0.01
# Episode: 366/500, score: 9, epsilon: 0.01
# Episode: 367/500, score: 11, epsilon: 0.01
# Episode: 368/500, score: 9, epsilon: 0.01
# Episode: 369/500, score: 9, epsilon: 0.01
# Episode: 370/500, score: 9, epsilon: 0.01
# Episode: 371/500, score: 9, epsilon: 0.01
# Episode: 372/500, score: 9, epsilon: 0.01
# Episode: 373/500, score: 9, epsilon: 0.01
# Episode: 374/500, score: 9, epsilon: 0.01
# Episode: 375/500, score: 9, epsilon: 0.01
# Episode: 376/500, score: 9, epsilon: 0.01
# Episode: 377/500, score: 9, epsilon: 0.01
# Episode: 378/500, score: 9, epsilon: 0.01
# Episode: 379/500, score: 9, epsilon: 0.01
# Episode: 380/500, score: 9, epsilon: 0.01
# Episode: 381/500, score: 9, epsilon: 0.01
# Episode: 382/500, score: 9, epsilon: 0.01
# Episode: 383/500, score: 9, epsilon: 0.01
# Episode: 384/500, score: 9, epsilon: 0.01
# Episode: 385/500, score: 9, epsilon: 0.01
# Episode: 386/500, score: 9, epsilon: 0.01
# Episode: 387/500, score: 9, epsilon: 0.01
# Episode: 388/500, score: 9, epsilon: 0.01
# Episode: 389/500, score: 9, epsilon: 0.01
# Episode: 390/500, score: 9, epsilon: 0.01
# Episode: 391/500, score: 11, epsilon: 0.01
# Episode: 392/500, score: 9, epsilon: 0.01
# Episode: 393/500, score: 9, epsilon: 0.01
# Episode: 394/500, score: 9, epsilon: 0.01
# Episode: 395/500, score: 9, epsilon: 0.01
# Episode: 396/500, score: 9, epsilon: 0.01
# Episode: 397/500, score: 9, epsilon: 0.01
# Episode: 398/500, score: 9, epsilon: 0.01
# Episode: 399/500, score: 9, epsilon: 0.01
# Episode: 400/500, score: 9, epsilon: 0.01
# Episode: 401/500, score: 9, epsilon: 0.01
# Episode: 402/500, score: 11, epsilon: 0.01
# Episode: 403/500, score: 9, epsilon: 0.01
# Episode: 404/500, score: 9, epsilon: 0.01
# Episode: 405/500, score: 9, epsilon: 0.01
# Episode: 406/500, score: 9, epsilon: 0.01
# Episode: 407/500, score: 9, epsilon: 0.01
# Episode: 408/500, score: 9, epsilon: 0.01
# Episode: 409/500, score: 9, epsilon: 0.01
# Episode: 410/500, score: 9, epsilon: 0.01
# Episode: 411/500, score: 9, epsilon: 0.01
# Episode: 412/500, score: 9, epsilon: 0.01
# Episode: 413/500, score: 9, epsilon: 0.01
# Episode: 414/500, score: 9, epsilon: 0.01
# Episode: 415/500, score: 9, epsilon: 0.01
# Episode: 416/500, score: 9, epsilon: 0.01
# Episode: 417/500, score: 9, epsilon: 0.01
# Episode: 418/500, score: 9, epsilon: 0.01
# Episode: 419/500, score: 9, epsilon: 0.01
# Episode: 420/500, score: 9, epsilon: 0.01
# Episode: 421/500, score: 9, epsilon: 0.01
# Episode: 422/500, score: 9, epsilon: 0.01
# Episode: 423/500, score: 9, epsilon: 0.01
# Episode: 424/500, score: 9, epsilon: 0.01
# Episode: 425/500, score: 9, epsilon: 0.01
# Episode: 426/500, score: 9, epsilon: 0.01
# Episode: 427/500, score: 9, epsilon: 0.01
# Episode: 428/500, score: 9, epsilon: 0.01
# Episode: 429/500, score: 9, epsilon: 0.01
# Episode: 430/500, score: 9, epsilon: 0.01
# Episode: 431/500, score: 9, epsilon: 0.01
# Episode: 432/500, score: 9, epsilon: 0.01
# Episode: 433/500, score: 9, epsilon: 0.01
# Episode: 434/500, score: 9, epsilon: 0.01
# Episode: 435/500, score: 9, epsilon: 0.01
# Episode: 436/500, score: 9, epsilon: 0.01
# Episode: 437/500, score: 9, epsilon: 0.01
# Episode: 438/500, score: 9, epsilon: 0.01
# Episode: 439/500, score: 9, epsilon: 0.01
# Episode: 440/500, score: 9, epsilon: 0.01
# Episode: 441/500, score: 11, epsilon: 0.01
# Episode: 442/500, score: 9, epsilon: 0.01
# Episode: 443/500, score: 9, epsilon: 0.01
# Episode: 444/500, score: 9, epsilon: 0.01
# Episode: 445/500, score: 9, epsilon: 0.01
# Episode: 446/500, score: 9, epsilon: 0.01
# Episode: 447/500, score: 9, epsilon: 0.01
# Episode: 448/500, score: 9, epsilon: 0.01
# Episode: 449/500, score: 9, epsilon: 0.01
# Episode: 450/500, score: 9, epsilon: 0.01
# Episode: 451/500, score: 9, epsilon: 0.01
# Episode: 452/500, score: 9, epsilon: 0.01
# Episode: 453/500, score: 9, epsilon: 0.01
# Episode: 454/500, score: 9, epsilon: 0.01
# Episode: 455/500, score: 9, epsilon: 0.01
# Episode: 456/500, score: 9, epsilon: 0.01
# Episode: 457/500, score: 9, epsilon: 0.01
# Episode: 458/500, score: 9, epsilon: 0.01
# Episode: 459/500, score: 9, epsilon: 0.01
# Episode: 460/500, score: 9, epsilon: 0.01
# Episode: 461/500, score: 9, epsilon: 0.01
# Episode: 462/500, score: 9, epsilon: 0.01
# Episode: 463/500, score: 11, epsilon: 0.01
# Episode: 464/500, score: 9, epsilon: 0.01
# Episode: 465/500, score: 9, epsilon: 0.01
# Episode: 466/500, score: 11, epsilon: 0.01
# Episode: 467/500, score: 9, epsilon: 0.01
# Episode: 468/500, score: 9, epsilon: 0.01
# Episode: 469/500, score: 9, epsilon: 0.01
# Episode: 470/500, score: 9, epsilon: 0.01
# Episode: 471/500, score: 9, epsilon: 0.01
# Episode: 472/500, score: 11, epsilon: 0.01
# Episode: 473/500, score: 9, epsilon: 0.01
# Episode: 474/500, score: 9, epsilon: 0.01
# Episode: 475/500, score: 9, epsilon: 0.01
# Episode: 476/500, score: 9, epsilon: 0.01
# Episode: 477/500, score: 9, epsilon: 0.01
# Episode: 478/500, score: 9, epsilon: 0.01
# Episode: 479/500, score: 9, epsilon: 0.01
# Episode: 480/500, score: 9, epsilon: 0.01
# Episode: 481/500, score: 9, epsilon: 0.01
# Episode: 482/500, score: 11, epsilon: 0.01
# Episode: 483/500, score: 9, epsilon: 0.01
# Episode: 484/500, score: 9, epsilon: 0.01
# Episode: 485/500, score: 9, epsilon: 0.01
# Episode: 486/500, score: 9, epsilon: 0.01
# Episode: 487/500, score: 9, epsilon: 0.01
# Episode: 488/500, score: 9, epsilon: 0.01
# Episode: 489/500, score: 9, epsilon: 0.01
# Episode: 490/500, score: 9, epsilon: 0.01
# Episode: 491/500, score: 9, epsilon: 0.01
# Episode: 492/500, score: 9, epsilon: 0.01
# Episode: 493/500, score: 9, epsilon: 0.01
# Episode: 494/500, score: 9, epsilon: 0.01
# Episode: 495/500, score: 9, epsilon: 0.01
# Episode: 496/500, score: 9, epsilon: 0.01
# Episode: 497/500, score: 9, epsilon: 0.01
# Episode: 498/500, score: 9, epsilon: 0.01
# Episode: 499/500, score: 9, epsilon: 0.01
# Episode: 500/500, score: 9, epsilon: 0.01
